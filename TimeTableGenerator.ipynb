# %% [markdown]
# <a href="https://colab.research.google.com/github/ali-dot-com/TimeTableGenerator/blob/main/TimeTableGenerator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Installing Necessary Libraries**

# %%
# !pip install pandas langchain openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.0/974.0 kB 11.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.5/325.5 kB 21.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.7/314.7 kB 23.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.7/142.7 kB 1.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.1
#     Uninstalling packaging-24.1:
#       Successfully uninstalled packaging-24.1
# ...

# %% [markdown]
# # **Reading the excel file**

# %%
import pandas as pd

# Load the Excel file
file_path = './data.xlsx'
student_data = pd.read_excel(file_path)

# Display the first few rows to understand the data structure
student_data.head()
# Out:
# Empty DataFrame
# Columns: [Name, Field of study, Year of study, List of subjects, Preferred Learning Styles, Personal Objectives, Challenges, Extracurricular activities]
# Index: []

# %% [markdown]
# # **Generating Dummy Data**

# %%
import pandas as pd

# Define sample data for 5 students
data = {
    'Name': ['Catherine Brown', 'David Wilson', 'Eva White'],
    'Field of study': ['Biology', 'Physics', 'Arts'],
    'Year of study': [1, 4, 2],
    'List of subjects': ['Biology, Chemistry, English', 'Physics, Math, PE', 'Literature, Art, History'],
    'Preferred Learning style': ['Kinesthetic', 'Visual', 'Auditory'],
    'Personal Objectives': ['Win a science competition', 'Become a team captain', 'Excel in arts'],
    'Challenges': ['Managing time for all subjects', 'Improving fitness', 'Balancing arts and academics'],
    'Extracurricular activities': ['Swimming, Science Club', 'Basketball, Robotics', 'Drama, Painting']
}

# Create a DataFrame
df = pd.DataFrame(data)

print(df)
# Write the DataFrame to an Excel file
output_file_path = './student_data_updated.xlsx'
df.to_excel(output_file_path, index=False)
print(f"Data written to {output_file_path}")
# Out:
#               Name Field of study  Year of study             List of subjects  \
# 0  Catherine Brown        Biology              1  Biology, Chemistry, English
# 1     David Wilson        Physics              4            Physics, Math, PE
# 2        Eva White           Arts              2     Literature, Art, History
#
#   Preferred Learning style        Personal Objectives  \
# 0              Kinesthetic  Win a science competition
# 1                   Visual      Become a team captain
# 2                 Auditory              Excel in arts
#
#                        Challenges Extracurricular activities
# 0  Managing time for all subjects     Swimming, Science Club
# 1               Improving fitness       Basketball, Robotics
# 2    Balancing arts and academics            Drama, Painting
# Data written to ./student_data_updated.xlsx

# %% [markdown]
# # **Reading the New Excel File**

# %%
import pandas as pd

# Load the Excel file
file_path = './student_data_updated.xlsx'
student_data = pd.read_excel(file_path)

# Display the first few rows to understand the data structure
student_data.head()
# Out:
#               Name Field of study  Year of study             List of subjects  \
# 0  Catherine Brown        Biology              1  Biology, Chemistry, English
# 1     David Wilson        Physics              4            Physics, Math, PE
# 2        Eva White           Arts              2     Literature, Art, History
#
#   Preferred Learning style        Personal Objectives  \
# 0              Kinesthetic  Win a science competition
# 1                   Visual      Become a team captain
# 2                 Auditory              Excel in arts
#
#                        Challenges Extracurricular activities
# 0  Managing time for all subjects     Swimming, Science Club
# 1               Improving fitness       Basketball, Robotics
# 2    Balancing arts and academics            Drama, Painting
